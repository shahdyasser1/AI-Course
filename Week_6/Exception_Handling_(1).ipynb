# %% [markdown]
# # Exception
#
# run time errors

# %%
a = 0
b = 1

print(b / a)
print("Hello")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-697/3000886225.py in <cell line: 0>()
#       2 b = 1
#       3
# ----> 4 print(b / a)
#       5 print("Hello")
#
# ZeroDivisionError: division by zero

# %%
print("7" + 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3553451212.py in <cell line: 0>()
# ----> 1 print("7" + 4)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("anas"*4)
# Out:
# anasanasanasanas

# %%
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1056546137.py in <cell line: 0>()
# ----> 1 print(y)
#
# NameError: name 'y' is not defined

# %% [markdown]
# # Exception names
#
# 1. ImportError
# 2. IndexError
# 3. NameError
# 4. SyntaxError
# 5. TypeError
# 6. ValueError
#
#
# # Exception Handling
#
# try - a block that might contains an exception
#
# except - contains the exception message

# %% [markdown]
# # ValueError

# %%
a = int(input("please enter a number"))
b = int(input("please enter a number"))
print(a/b)
# Out:
# please enter a number10
# please enter a numberhj
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-705161202.py in <cell line: 0>()
#       1 a = int(input("please enter a number"))
# ----> 2 b = int(input("please enter a number"))
#       3 print(a/b)
#
# ValueError: invalid literal for int() with base 10: 'hj'

# %%
try:                            # code that may cause an error
    a = int(input("please enter a number"))
    b = int(input("please enter a number"))
    print(a/b)
except Exception as h:            # code that runs if error happens
    print("An error occured.")
    print(h)

print("Hello World")
# Out:
# please enter a number4
# please enter a numbera
# An error occured.
# invalid literal for int() with base 10: 'a'
# Hello World

# %% [markdown]
# # NameError

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-289819153.py in <cell line: 0>()
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
a = 10
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-651552423.py in <cell line: 0>()
#       1 a = 10
# ----> 2 print(b)
#
# NameError: name 'b' is not defined

# %%
my_fun()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1929737164.py in <cell line: 0>()
# ----> 1 my_fun()
#
# NameError: name 'my_fun' is not defined

# %%
try:
    print(x)
except NameError:
    print("Variable is not defined")
# Out:
# Variable is not defined

# %% [markdown]
# # ZeroDivisionError

# %%
try:
    a = 7
    b = 0
    # print("H"+7)
    print(a/b)

except ZeroDivisionError:
    print("An error occured. Do not divide by zero")
# Out:
# An error occured. Do not divide by zero

# %%
help(ZeroDivisionError)
# Out:
# Help on class ZeroDivisionError in module builtins:
#
# class ZeroDivisionError(ArithmeticError)
#  |  Second argument to a division or modulo operation was zero.
#  |
#  |  Method resolution order:
#  |      ZeroDivisionError
#  |      ArithmeticError
#  |      Exception
#  |      BaseException
#  |      object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __reduce__(...)
#  |      Helper for pickle.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setattr__(self, name, value, /)
#  |      Implement setattr(self, name, value).
#  |
#  |  __setstate__(...)
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  with_traceback(...)
#  |      Exception.with_traceback(tb) --
#  |      set self.__traceback__ to tb and return self.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from BaseException:
#  |
#  |  __cause__
#  |      exception cause
#  |
#  |  __context__
#  |      exception context
#  |
#  |  __dict__
#  |
#  |  __suppress_context__
#  |
#  |  __traceback__
#  |
#  |  args

# %%
try:
    a = 7
    b = 0
    print(a/b)
    print("Finish")
except ZeroDivisionError  as e:
    print("An error occured. Do not divide by zero")
    print(e)
# Out:
# An error occured. Do not divide by zero
# division by zero

# %%
try:
    a = 7
    b = 2
    print(a/b)
    print("Finish"+3)
except ZeroDivisionError:
    print("An error occured. Do not divide by zero")
# Out:
# 3.5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-697/170665039.py in <cell line: 0>()
#       3     b = 2
#       4     print(a/b)
# ----> 5     print("Finish"+3)
#       6 except ZeroDivisionError:
#       7     print("An error occured. Do not divide by zero")
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = int(input('Please enter 1st N : '))
b = int(input('Please enter 2st N : '))
try:
  print(a/b)
except ZeroDivisionError:
    print("An error occured. Do not divide by zero")

print("Hello you are on the right way")
print(10+2)
# Out:
# Please enter 1st N : 10
# Please enter 2st N : 0
# An error occured. Do not divide by zero
# Hello you are on the right way
# 12

# %% [markdown]
# # TypeError

# %%
x = 5
x()   # TypeError
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-28439885.py in <cell line: 0>()
#       1 x = 5
# ----> 2 x()   # TypeError
#
# TypeError: 'int' object is not callable

# %%
try:
    x = 5
    x()
except TypeError:
    print("TypeError: You are trying to call a non-callable object")
# Out:
# TypeError: You are trying to call a non-callable object

# %% [markdown]
# # IndexError

# %%
try:
    l = [1,2,3]
    print(l[5])
except IndexError:
    print("Index out of range")
# Out:
# Index out of range

# %% [markdown]
# # KeyError

# %%
try:
    d = {"a": 1}
    print(d["b"])
except KeyError:
    print("Key not found")
# Out:
# Key not found

# %%
try:
    a = 10
    # print(10/0)
    # print("Hi" + a) # HI + 10
    print(v / 5)
except ZeroDivisionError:
    print("An error occured. Do not divide by zero")
except TypeError:
    print("Error Occured")
except NameError:
   print("Name Error")
# Out:
# Name Error

# %%
x=int(input())
# Out:
# anas
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9039/2179133089.py in <cell line: 0>()
# ----> 1 x=int(input())
#
# ValueError: invalid literal for int() with base 10: 'anas'

# %%
try:
  a = int(input('Please enter 1st N : '))
  b = int(input('Please enter 2st N : '))
  print(a/b)
except ZeroDivisionError:
    print("An error occured. Do not divide by zero")
except ValueError:
    print("You can't enter string to divide")
except Exception as e:
    print("Something went wrong",e )

print("Hello you are on the right way")
for i in range(0,6):
  print(i*5)
# Out:
# Please enter 1st N : a
# You can't enter string to divide
# Hello you are on the right way
# 0
# 5
# 10
# 15
# 20
# 25

# %%
try:
    a = 10
    # print(10/0)
    print("Hi" + a)
    print(a / 2)
    print(5/0)
except ZeroDivisionError :
    print("An error occured. Do not divide by zero")
except (TypeError, ValueError,KeyError) as e:
    print("Error Occured",e )
# Out:
# Error Occured can only concatenate str (not "int") to str

# %%
try:
    w = "indore"
    print(w/0)
except Exception as h:
    print("Something went wrong",h)
# Out:
# Something went wrong unsupported operand type(s) for /: 'str' and 'int'

# %%
w = "indore"
print(w/0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-dff75862ee41> in <cell line: 2>()
#       1 w = "indore"
# ----> 2 print(w/0)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# # finally

# %%
try:
    print("Hello")
except:
    print("Error")
finally:
    print("finally block")
# Out:
# Hello
# finally block

# %%
try:
    print("Hello" + 5)
except:
    print("Error")
finally:
    print("finally block")
# Out:
# Error
# finally block

# %%
try:
    print(1)
except:
    print(2)
finally:
    print(3)
# Out:
# 1
# 3

# %% [markdown]
# # else--> بتتنفذ لو مفيش أي error

# %%
try:
    x = int(input())
    print(10 / x)
except:
    print("Error occurred")
else:
    print("Code executed successfully")
# Out:
# 2
# 5.0
# Code executed successfully

# %%
try:
    print(1)
except:
    print(2)
else:
    print(4)
finally:
    print(3)
# Out:
# 1
# 4
# 3

# %%
try:
    # code that may cause an error
except:
    # runs if error happens
else:
    # runs if NO error happens
finally:
    # runs ALWAYS

# %%
try:
    x = int(input("Enter a number: "))
    print(10 / x)
except ValueError:
    print("Please enter a valid number")
except ZeroDivisionError:
    print("Cannot divide by zero")
else:
    print("Calculation successful")
# Out:
# Enter a number: 0
# Cannot divide by zero

# %%
try:
    f = open("data.txt")
    print(f.read())
except FileNotFoundError:
    print("File not found")
finally:
    print("End of program")
# Out:
# File not found
# End of program
