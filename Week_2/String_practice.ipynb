# %% [markdown]
# Part 1: Python Basics
# Question 1: Print
#
# Write a program that:
#
# Prints your name
#
# Prints today’s date
#
# Each one should be printed on a separate line

# %%
print("shahd",end=" ")
print("26-02-2026")
# Out:
# shahd 26-02-2026

# %%
print(5==5)
# Out:
# True

# %% [markdown]
# Question 2: Variables
#
# Write a program that:
#
# Defines two variables first_name and last_name
#
# Prints the full name in one line with a space between them

# %%
first_name="shahd"
last_name="yasser"
print(first_name,last_name)
# Out:
# shahd yasser

# %%
print(first_name+' '+last_name)
# Out:
# shahd yasser

# %% [markdown]
# Question 3: Data Types
#
# Write a program that:
#
# Defines a variable age with an integer value
#
# Defines a variable gpa with a float value
#
# Prints the data type of each variable using type()

# %%
age=20
gpa=3.65
print(type(age))
print(type(gpa))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# Write a program that:
#
# Asks the user to enter two numbers
#
# Prints:
#
# The sum
#
# The difference
#
# The product
#
# The division result

# %%
a=int(input())
b=int(input())
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 10
# 5
# 15
# 5
# 50
# 2.0

# %% [markdown]
# Question 5: Type Conversion
#
# Write a program that:
#
# Asks the user to enter two numbers
#
# Adds them before converting them to integers
#
# Adds them after converting them to integers
#
# Prints both results

# %%
n=input()
m=input()
print(n+m)
# Out:
# 5
# 10
# 510

# %%
type(n+m)
# Out:
# str

# %%
n=int(n)
m=int(m)
print(n+m)
# Out:
# 15

# %% [markdown]
# Part 2: Strings Basics
# Question 8: String Concatenation
#
# Write a program that:
#
# Defines two string variables
#
# Concatenates them into one sentence
#
# Prints the result

# %%
s1="Hello"
s2="world"
print(s1,s2)
# Out:
# Hello world

# %% [markdown]
# Question 9: String Indexing
#
# Write a program that:
#
# Defines a string with a country name
#
# Prints:
#
# The first character
#
# The last character

# %%
c="Egypt"
print(c[0])
# Out:
# E

# %%
c[-1]
# Out:
# 't'

# %% [markdown]
# Question 10: String Length
#
# Write a program that:
#
# Asks the user to enter their name
#
# Prints the number of characters in the name

# %% [markdown]
# Part 3: String Slicing
# Question 11: String Slicing
#
# Write a program that:
#
# Defines the string "Communication"
#
# Prints the first 5 characters

# %%
name=input()
print(len(name))
# Out:
# shahd
# 5

# %%
s="AhmedA"
s.count('A')
# Out:
# 2

# %%
s="Communication"
s[0:5]
# Out:
# 'Commu'

# %% [markdown]
# Question 12: Reverse String
#
# Write a program that:
#
# Asks the user to enter a word
#
# Prints the word reversed

# %%
s=input()  #reverse
s[::-1]
# Out:
# Ahmed
# 'demhA'

# %% [markdown]
# Question 13: Replace Using Slicing
#
# Write a program that:
#
# Defines a string
#
# Replaces one character with another using slicing

# %%
s="Ahmed"
new_str="B"+s[1:]
new_str
# Out:
# 'Bhmed'

# %% [markdown]
# Part 4: String Functions
# Question 14: Upper and Lower
#
# Write a program that:
#
# Asks the user to enter a word
#
# Prints the word in uppercase
#
# Prints the word in lowercase

# %%
s=input()
print(s.upper())
s.lower()
# Out:
# Shahd
# SHAHD
# 'shahd'

# %%
a="ahmed go to school"
a.title()
# Out:
# 'Ahmed Go To School'

# %%
a="ahmed go to school"
a.capitalize()
# Out:
# 'Ahmed go to school'

# %%
a="ahmed go to school"
a.upper()
# Out:
# 'AHMED GO TO SCHOOL'

# %%
a="ahmed go to school"
a.startswith('a')
# Out:
# True

# %%
a="ahmed go to school"
a.startswith('b')
# Out:
# False

# %%
a="ahmed go to school"
a.endswith('b')
# Out:
# False

# %%
a="ahmed go to school "
a.endswith(' ')
# Out:
# True

# %%
a="    ahmed go to school   "
a.strip()
# Out:
# 'ahmed go to school'

# %%
a="    ahmed go to school   "
a.rstrip()
# Out:
# '    ahmed go to school'

# %%
a="    ahmed go to school   "
a.lstrip()
# Out:
# 'ahmed go to school   '

# %% [markdown]
# Question 15: Split
#
# Write a program that:
#
# Defines a sentence
#
# Splits it into a list of words
#
# Prints the list

# %%
s="I%%%LOVE%AI%AND DATA SCIENCE"
l=s.split('%')
l
# Out:
# ['I', '', '', 'LOVE', 'AI', 'AND DATA SCIENCE']

# %% [markdown]
# Question 16: Replace
#
# Write a program that:
#
# Defines a sentence with a repeated word
#
# Replaces the word with another word only once

# %%
s="AI Hello Bread AI python AI"
s.replace("AI","Data")
# Out:
# 'Data Hello Bread Data python Data'

# %%
s="AI Hello Bread AI python AI"
print(s.split())
#keep first 2 "AI" and replace the last one with "Data"
print(s[0:3]+s[3:].replace("AI","Data"))
# Out:
# ['AI', 'Hello', 'Bread', 'AI', 'python', 'AI']
# AI Hello Bread Data python Data

# %% [markdown]
# Question 17: Join
#
# Write a program that:
#
# Defines a list of words
#
# Joins them into a single sentence using join()

# %%
l=['AI', 'Hello', 'Bread', 'AI', 'python', 'AI']
s=" ".join(l)
s
# Out:
# 'AI Hello Bread AI python AI'

# %% [markdown]
# Question 3
#
# Write a program that:
#
# Defines a sentence
#
# Capitalizes the first character of the sentence
#
# Prints the result

# %%
s="i am hungry"
s.capitalize()
# Out:
# 'I am hungry'

# %% [markdown]
# Part 2: split()
# Question 4
#
# Write a program that:
#
# Defines the string "Hello world,AUC,AI"
#
# Splits the string using , as a separator
#
# Prints the result

# %%
s="Hello,world,AUC,AI"
l=s.split(',')
print(l)
print(len(l))
# Out:
# ['Hello', 'world', 'AUC', 'AI']
# 4

# %% [markdown]
# Question 5
#
# Write a program that:
#
# Defines the string "Hello world egypt"
#
# Splits the string using the default separator
#
# Prints the list of words

# %%
s=input().split()
s
# Out:
# Hello World Egypt
# ['Hello', 'World', 'Egypt']

# %% [markdown]
# Question 6
#
# Write a program that:
#
# Asks the user to enter a sentence
#
# Splits the sentence into words
#
# Prints the number of words

# %%
s=input().split()
len(s)
# Out:
# shahd yasser hassan ali
# 4

# %% [markdown]
# Part 3: String Indexing
# Question 9
#
# Write a program that:
#
# Defines the string "abcdef"
#
# Prints:
#
# The first character
#
# The third character
#
# The fourth character

# %%
s="abcdef"
s[0]
# Out:
# 'a'

# %%
s[2]
# Out:
# 'c'

# %%
s[3]
# Out:
# 'd'

# %% [markdown]
# Question 10
#
# Write a program that:
#
# Defines a string
#
# Prints the characters at index 0, 2, and 3 concatenated together

# %%
s="abcdef"
print(s[0]+s[2]+s[3])
# Out:
# acd

# %% [markdown]
# Question 11
#
# Write a program that:
#
# Asks the user to enter a word
#
# Prints the first and last characters of the word

# %%
word=input()
print(word[0])
word[-1]
# Out:
# shahd
# s
# 'd'

# %% [markdown]
# Challenge Question
#
# Write a program that:
#
# Asks the user to enter a sentence
#
# Capitalizes the first character
#
# Splits the sentence into words

# %%
s=input().capitalize().split(',')
s
# Out:
# hello world computer science
# ['Hello world computer science']

# %% [markdown]
# Challenge Question
#
# Write a program that:
#
# Asks the user to enter a sentence
#
# Prints:
#
# The number of characters
#
# The number of words
#
# The sentence in uppercase
#
# The sentence reversed

# %%
s="Hello,world,AUC,AI"
print(len(s))
# Out:
# 18

# %%
l=s.split(',')
print(len(l))
# Out:
# 4

# %%
s.upper()
# Out:
# 'HELLO,WORLD,AUC,AI'

# %%
s[::-1]
# Out:
# 'IA,CUA,dlrow,olleH'
