# %%
print("hello")
# Out:
# hello

# %%
print('hello')
# Out:
# hello

# %%
print("  i'm shahd yasser ")
# Out:
#   i'm shahd yasser

# %%
print('shahd')
# Out:
# shahd

# %%
print("shahd")
# Out:
# shahd

# %%
print("i'm shahd yasser")
# Out:
# i'm shahd yasser

# %%
print('  hello it"s me  ')
# Out:
#   hello it"s me

# %%
print("hi","ai and data science","zoom")
# Out:
# hi ai and data science zoom

# %%
print("hi")
print("ai and data science")
print("29-12-2025")
print("zoom")
# Out:
# hi
# ai and data science
# 29-12-2025
# zoom

# %%
first_name="shahd"
second_name='yasser'

# %%
one=1
One=1
ONE=1

# %%
print(first_name , "  ",second_name)
# Out:
# shahd    yasser

# %%
print('first_name' + "  "+"second_name")
# Out:
# first_name  second_name

# %%
print("shahd|")
# Out:
# shahd|

# %%
a=3
b=a
b=b+3
print(a)
print(b)
print(a+b)
# Out:
# 3
# 6
# 9

# %%
name="ali"
last_name='ali'
#########################
name="   my name's ali  "

last_name='   my name"s ali   '

last_name ='''      name's ali"emad    '''
last_name ="""      ''' name's ali"emad '''     """

# %%
print(type(name))
print(type(last_name))
# Out:
# <class 'str'>
# <class 'str'>

# %%
print(name)
print(last_name)
# Out:
#    my name's ali
#       ''' name's ali"emad '''

# %%
print(5+5)  # sum
# Out:
# 10

# %%
print(10-2)  # subtract
# Out:
# 8

# %%
print(2*3)  # multiply
# Out:
# 6

# %%
print(2**3)  # power
# Out:
# 8

# %%
gpa=3.8
print(gpa)
# Out:
# 3.8

# %%
print(17/3)   # division
# Out:
# 5.666666666666667

# %%
print(17//3)   # floor division    ->> result is integer not decimal
# Out:
# 5

# %%
print(10 % 2)  # moduls   --> reminder
# Out:
# 0

# %%
print(11%2)
# Out:
# 1

# %%
print(type(gpa))
# Out:
# <class 'float'>

# %%
gpa=4
print(gpa)
# Out:
# 4

# %%
print(type(gpa))
# Out:
# <class 'int'>

# %%
print('3+5')
# Out:
# 3+5

# %%
print(3+5)
# Out:
# 8

# %%
print(type(17/3))
# Out:
# <class 'float'>

# %%
print(17/3)
# Out:
# 5.666666666666667

# %%
age=20
gpa=3.65
name='shahd'
print(age,"\t",gpa)
# Out:
# 20 	 3.65

# %%
bo=False
bo_1=True
print(bo)
print(type(bo))
print(type(bo_1))
print(bo_1)
# Out:
# False
# <class 'bool'>
# <class 'bool'>
# True

# %%
# sum
numberone=10
numbertwo=20

add=numberone + numbertwo
print(type(add))
print(add)
# Out:
# <class 'int'>
# 30

# %%
# case senseteve
numberone=10
numbertwo=20

add=Numberone+numberTwo
print(type(add))
print(add)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-203/376923523.py in <cell line: 0>()
#       3 numbertwo=20
#       4
# ----> 5 add=Numberone+numberTwo
#       6 print(type(add))
#       7 print(add)
#
# NameError: name 'Numberone' is not defined

# %%
number_1=10.5
number_2=20
add=number_1+number_2
print(add) # sum
print(type(add))
# Out:
# 30.5
# <class 'float'>

# %%
number_1=30
number_2=20
sub=number_1-number_2
print(sub) # sub
print(type(sub))
# Out:
# 10
# <class 'int'>

# %%
number_1=30
number_2=20
multi=number_1*number_2
print(multi) # multi
print(type(multi))
# Out:
# 600
# <class 'int'>

# %%
number_1=30
number_2=20
div=number_1 / number_2
print(div) # div
print(type(div))
# Out:
# 1.5
# <class 'float'>

# %%
number_1=30
number_2=20
div=number_1 // number_2
print(div) # floor div
print(type(div))
# Out:
# 1
# <class 'int'>

# %%
number_1=2
number_2=3
pow=number_1 ** number_2
print(pow) # power
print(type(pow))
# Out:
# 8
# <class 'int'>

# %%
number_1=11
number_2=2
mod=number_1 % number_2
print(mod) # mod
print(type(mod))
# Out:
# 1
# <class 'int'>

# %%
name='shahd'
print(name)
print(type(name))
# Out:
# shahd
# <class 'str'>

# %%
name=input('Enter Ur Name:')              # for user
print(name)
print(type(name))
# Out:
# Enter Ur Name:shahd yasser
# shahd yasser
# <class 'str'>

# %%
number=input() # for user
print(number)
print(type(number))
# Out:
# 15
# 15
# <class 'str'>

# %%
numone=input('enter first number:')
numtwo=input('enter second number:')
add=numone+numtwo
print(add)
# Out:
# enter first number:20
# enter second number:30
# 2030

# %%
numone=int(input('enter first number:'))
numtwo=int(input('enter second number:'))
add=numone+numtwo
print(add)
# Out:
# enter first number:20
# enter second number:30
# 50

# %%
numone=float(input('enter first number:'))
numtwo=float(input('enter second number:'))
add=numone+numtwo
print(add)
print(type(add))
# Out:
# enter first number:10
# enter second number:20
# 30.0
# <class 'float'>

# %%
price_of_product=float(input('enter price of product:'))
total_cost=price_of_product+(price_of_product*0.14)
print("this is total cost:",total_cost,"$")
# Out:
# enter price of product:450
# this is total cost: 513.0 $

# %%
grade_1=float(input('enter grade_1:'))
grade_2=float(input('enter grade_2:'))
grade_3=float(input('enter grade_3:'))
avg=(grade_1+grade_2+grade_3)/3
print(avg)
# Out:
# enter grade_1:2.5
# enter grade_2:3.6
# enter grade_3:4
# 3.3666666666666667

# %%
name=input("enter ur name: ")
gpa=float(input("enter ur gpa: "))
print(name," ",gpa)
# Out:
# enter ur name: shahd
# enter ur gpa: 3.65
# shahd   3.65

# %%
age = int(input("Enter your age: "))
current_year=int(input("enter current year:"))
birth_year = current_year - age
print(f"You were likely born in {birth_year} , ai data.")
# Out:
# Enter your age: 20
# enter current year:2026
# You were likely born in 2006 , ai data.

# %%
print(10==10)  # equal equal
# Out:
# True

# %%
print(10!=10)  # not equal
# Out:
# False

# %%
gpa=3.5
print(gpa==4)
# Out:
# False

# %%
name='Mohamed'

# %%
print(name=='mohamed')
# Out:
# False
